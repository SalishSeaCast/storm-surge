# %% [markdown]
# This notebook examines the relationship between surges on the Pacific Coast. Timing and amplitude?
#
# * Tofino
# * Port Hardy
# * Bamfield
# * Toke Point
# * Neah Bay

# %%
from salishsea_tools.nowcast import residuals
from salishsea_tools.nowcast import figures
from salishsea_tools import stormtools, tidetools

import pandas as pd

import matplotlib.pyplot as plt
import datetime
from dateutil import tz
import arrow
import requests
from cStringIO import StringIO
import numpy as np

# %matplotlib inline

# %%
stns_NOAA ={'NeahBay': 9443090, 'TokePoint': 9440910}
stns_DFO = {'Tofino': 8615,'Bamfield': 8545, 'PortHardy': 8408}
MSLs={'Tofino': 2.103, 'Bamfield': 2.035, 'PortHardy': 2.896}

# %%
def dateParserMeasured(s):

    PST=tz.tzoffset("PST",-28800)
    # Convert the string to a datetime object
    unaware = datetime.datetime.strptime(s, "%Y/%m/%d %H:%M")
    # Add in the local time zone (Canada/Pacific)
    aware = unaware.replace(tzinfo=PST)
    # Convert to UTC
    return aware.astimezone(tz.tzutc())

# %%
def get_NOAA(station_no, start_date, end_date, product):
    """Retrieves recent NOAA water levels from a station in a given date range.

    NOAA water levels are at 6 minute intervals and are relative to
    mean sea level.
    See: http://tidesandcurrents.noaa.gov/stations.html?type=Water+Levels.

    :arg station_no: NOAA station number.
    :type station_no: int

    :arg start_date: The start of the date range; e.g. 01-Jan-2014.
    :type start_date: str

    :arg end_date: The end of the date range; e.g. 02-Jan-2014.
    :type end_date: str

    :returns: DataFrame object (obs) with time and wlev columns,
              among others that are irrelevant.
    """

    # Time range
    st_ar = arrow.Arrow.strptime(start_date, '%d-%b-%Y')
    end_ar = arrow.Arrow.strptime(end_date, '%d-%b-%Y')

    base_url = (
        'http://tidesandcurrents.noaa.gov/api/datagetter?')
    params = {
        'product': product,
        'application': 'NOS.COOPS.TAC.WL',
        'begin_date': st_ar.format('YYYYMMDD'),
        'end_date': end_ar.format('YYYYMMDD'),
        'datum': 'STND',
        'station': str(station_no),
        'time_zone': 'GMT',
        'units': 'metric',
        'format': 'csv',
    }
    response = requests.get(base_url, params=params)

    fakefile = StringIO(response.content)
    try:
        obs = pd.read_csv(
            fakefile, parse_dates=[0], date_parser=figures.dateparse_NOAA)
    except ValueError:
        data = {'Date Time': st_ar.datetime, ' Water Level': float('NaN')}
        obs = pd.DataFrame(data=data, index=[0])
    if product == 'hourly_height':
        obs = obs.rename(columns={'Date Time': 'time', ' Water Level': 'wlev'})
    elif product == 'predictions':
        obs = obs.rename(columns={'Date Time': 'time', ' Prediction': 'pred'})
    return obs

# %%
def compare_residuals(year):
    fig,ax = plt.subplots(1,1,figsize=(15,5))
    tides = {}; obs={}; res={}; time={}

    #NOAA
    start = '01-Jan-{}'.format(year); end = '31-Dec-{}'.format(year)
    for key, num in stns_NOAA.iteritems():
        tides = get_NOAA(num,start,end,'predictions')
        obs = get_NOAA(num, start, end,'hourly_height')
        res[key] = residuals.calculate_residual(obs.wlev, obs.time, tides.pred,tides.time)
        time[key] = obs.time
        ax.plot(time[key],res[key],label=key,lw=1.5)
    
    #DFO
    for key,num in stns_DFO.iteritems():
        #tides
        fname ='forcing/{}_t_tide_compare8_31-Dec-{}_02-Jan-{}_snr2_filter.csv'.format(key,year-1,year+1)
        tides, msl = stormtools.load_tidal_predictions(fname)
        msl=MSLs[key]
        
        #observations
        filename ='wlev_{}_31-Dec-{}_02-Jan-{}.csv'.format(num,year-1,year+1)
        obs = pd.read_csv(filename,skiprows=7,parse_dates=[0],date_parser=dateParserMeasured)
        obs = obs.rename(columns={'Obs_date': 'time', 'SLEV(metres)': 'slev'})
        
        res[key] = residuals.calculate_residual(obs.slev, obs.time, tides.pred_all+msl,tides.time)
        time[key]=obs.time
        ax.plot(time[key],res[key],label=key,lw=1.5)
    
    ax.legend()
    ax.grid()
    
    return fig,ax,res,time

# %%
def compare_peaks(t1,t2,residuals,time):
    epoch = datetime.datetime(2006,1,1)
    epoch=epoch.replace(tzinfo=tz.tzutc())
    
    res_max={}
    time_max={}
    
    for key, res in residuals.iteritems():
        
        time_array = np.array(time[key])
        res_array = np.array(res)
        #truncate data
        inds = np.where(np.logical_and(time_array <= t2, time_array >= t1))
        
        res_trun = res_array[inds]
        time_trun = time_array[inds]
        
        ind_max = np.argmax(res_trun)
        res_max[key] = np.array([res_trun[ind_max]])
        date_max  = time_trun[ind_max]
        time_max[key] = np.array([(date_max-epoch).total_seconds()/3600])
    
        print '{}: Max residual: {}, Time max: {}'.format(key, res_max[key][0], date_max.strftime('%d-%b-%Y %H:%M') )
        
    res_d = pd.DataFrame(res_max)
    time_d = pd.DataFrame(time_max)
        
    return res_d, time_d

# %% [markdown]
# # 2006

# %% [markdown]
# Here, grab observations if needed, and run the tidal predictions.

# %%
yr=2006
start= '31-Dec-{}'.format(yr-1)
end = '02-Jan-{}'.format(yr+1)

for stn in ['Bamfield','PortHardy']:
    tidetools.get_dfo_wlev(stns_DFO[stn],start,end)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2048d9bbe9f9> in <module>()
#       4
#       5 for stn in ['Bamfield','PortHardy']:
# ----> 6     tidetools.get_dfo_wlev(stns_DFO[stn],start,end)
#       7
#
# /data/nsoontie/MEOPAR/tools/SalishSeaTools/salishsea_tools/tidetools.pyc in get_dfo_wlev(station_no, start_date, end_date)
#     103     # Go get the data from the DFO site
#     104     with requests.Session() as s:
# --> 105         s.post(base_url + form_handler, data=sitedata)
#     106         r = s.get(base_url + data_provider)
#     107     # Write the data to a text file
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in post(self, url, data, json, **kwargs)
#     502         """
#     503
# --> 504         return self.request('POST', url, data=data, json=json, **kwargs)
#     505
#     506     def put(self, url, data=None, **kwargs):
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     459         }
#     460         send_kwargs.update(settings)
# --> 461         resp = self.send(prep, **send_kwargs)
#     462
#     463         return resp
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/sessions.pyc in send(self, request, **kwargs)
#     571
#     572         # Send the request
# --> 573         r = adapter.send(request, **kwargs)
#     574
#     575         # Total elapsed time of the request (approximately)
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/adapters.pyc in send(self, request, stream, timeout, verify, cert, proxies)
#     368                     decode_content=False,
#     369                     retries=self.max_retries,
# --> 370                     timeout=timeout
#     371                 )
#     372
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, **response_kw)
#     542             httplib_response = self._make_request(conn, method, url,
#     543                                                   timeout=timeout_obj,
# --> 544                                                   body=body, headers=headers)
#     545
#     546             # If we're going to release the connection in ``finally:``, then
#
# /home/nsoontie/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/connectionpool.pyc in _make_request(self, conn, method, url, timeout, **httplib_request_kw)
#     370         try:
#     371             try:  # Python 2.7, use buffering of HTTP responses
# --> 372                 httplib_response = conn.getresponse(buffering=True)
#     373             except TypeError:  # Python 2.6 and older
#     374                 httplib_response = conn.getresponse()
#
# /home/nsoontie/anaconda/lib/python2.7/httplib.pyc in getresponse(self, buffering)
#    1071         response = self.response_class(*args, **kwds)
#    1072
# -> 1073         response.begin()
#    1074         assert response.will_close != _UNKNOWN
#    1075         self.__state = _CS_IDLE
#
# /home/nsoontie/anaconda/lib/python2.7/httplib.pyc in begin(self)
#     413         # read until we get a non-100 response
#     414         while True:
# --> 415             version, status, reason = self._read_status()
#     416             if status != CONTINUE:
#     417                 break
#
# /home/nsoontie/anaconda/lib/python2.7/httplib.pyc in _read_status(self)
#     369     def _read_status(self):
#     370         # Initialize with Simple-Response defaults
# --> 371         line = self.fp.readline(_MAXLINE + 1)
#     372         if len(line) > _MAXLINE:
#     373             raise LineTooLong("header line")
#
# /home/nsoontie/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     474             while True:
#     475                 try:
# --> 476                     data = self._sock.recv(self._rbufsize)
#     477                 except error, e:
#     478                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:

# %%
fig,ax,res,time = compare_residuals(2006)

# %% [markdown]
# ## Isolating several surge events

# %%
t1=datetime.datetime(2006,2,1)
t1=t1.replace(tzinfo=tz.tzutc())
t2=datetime.datetime(2006,2,7)
t2=t2.replace(tzinfo=tz.tzutc())

ax.set_xlim(t1,t2)

res_data, time_data =compare_peaks(t1,t2,res,time)

fig
# Out:
# Tofino: Max residual: 0.902445, Time max: 04-Feb-2006 14:00
# Bamfield: Max residual: 0.816296, Time max: 01-Feb-2006 02:00
# PortHardy: Max residual: 0.68015, Time max: 01-Feb-2006 04:00
# TokePoint: Max residual: 1.334, Time max: 04-Feb-2006 15:00
# NeahBay: Max residual: 0.636, Time max: 04-Feb-2006 16:00

# %%
t1=datetime.datetime(2006,12,11)
t1=t1.replace(tzinfo=tz.tzutc())
t2=datetime.datetime(2006,12,13)
t2=t2.replace(tzinfo=tz.tzutc())

ax.set_xlim(t1,t2)

res_d,time_d=compare_peaks(t1,t2,res,time)

res_data = res_data.append(res_d)
time_data =time_data.append(time_d)
fig
# Out:
# Tofino: Max residual: 0.921923, Time max: 12-Dec-2006 00:00
# Bamfield: Max residual: 0.841158, Time max: 12-Dec-2006 00:00
# PortHardy: Max residual: 0.454216, Time max: 12-Dec-2006 02:00
# TokePoint: Max residual: 0.893, Time max: 11-Dec-2006 22:00
# NeahBay: Max residual: 0.593, Time max: 12-Dec-2006 00:00

# %%
print time_data
# Out:
#    Bamfield  NeahBay  PortHardy  Tofino  TokePoint
# 0       746      832        748     830        831
# 0      8280     8280       8282    8280       8278

# %%
t1=datetime.datetime(2006,12,13)
t1=t1.replace(tzinfo=tz.tzutc())
t2=datetime.datetime(2006,12,16)
t2=t2.replace(tzinfo=tz.tzutc())

ax.set_xlim(t1,t2)

res_d,time_d=compare_peaks(t1,t2,res,time)

res_data = res_data.append(res_d)
time_data =time_data.append(time_d)
fig
# Out:
# Tofino: Max residual: 0.699467, Time max: 15-Dec-2006 06:00
# Bamfield: Max residual: 0.726103, Time max: 15-Dec-2006 06:00
# PortHardy: Max residual: 0.684264, Time max: 13-Dec-2006 16:00
# TokePoint: Max residual: 1.439, Time max: 15-Dec-2006 08:00
# NeahBay: Max residual: 0.65, Time max: 15-Dec-2006 06:00

# %%
t1=datetime.datetime(2006,11,11)
t1=t1.replace(tzinfo=tz.tzutc())
t2=datetime.datetime(2006,11,14)
t2=t2.replace(tzinfo=tz.tzutc())

ax.set_xlim(t1,t2)

res_d,time_d=compare_peaks(t1,t2,res,time)

res_data = res_data.append(res_d)
time_data =time_data.append(time_d)
fig
# Out:
# Tofino: Max residual: 0.491479, Time max: 13-Nov-2006 06:00
# Bamfield: Max residual: 0.523002, Time max: 13-Nov-2006 05:00
# PortHardy: Max residual: 0.336705, Time max: 13-Nov-2006 08:00
# TokePoint: Max residual: 1.142, Time max: 13-Nov-2006 08:00
# NeahBay: Max residual: 0.501, Time max: 13-Nov-2006 07:00

# %%
t1=datetime.datetime(2006,11,14)
t1=t1.replace(tzinfo=tz.tzutc())
t2=datetime.datetime(2006,11,17)
t2=t2.replace(tzinfo=tz.tzutc())

ax.set_xlim(t1,t2)

res_d,time_d=compare_peaks(t1,t2,res,time)

res_data = res_data.append(res_d)
time_data =time_data.append(time_d)
fig
# Out:
# Tofino: Max residual: 0.784133, Time max: 15-Nov-2006 19:00
# Bamfield: Max residual: 0.707483, Time max: 15-Nov-2006 21:00
# PortHardy: Max residual: 0.44256, Time max: 15-Nov-2006 22:00
# TokePoint: Max residual: 1.064, Time max: 16-Nov-2006 01:00
# NeahBay: Max residual: 0.63, Time max: 16-Nov-2006 01:00

# %%
fig,ax=plt.subplots(1,1,figsize=(8,8))
lists=['NeahBay','PortHardy','TokePoint','Bamfield']
colors=['g','c','b','r']
for key , c in zip(lists,colors):
    res_data.plot(x='Tofino',y=key,kind='scatter',ax=ax,color=c,label=key)

    ax.plot([0.2,1.6],[0.2,1.6],'-k')
ax.set_ylabel('Surge amplitude')
ax.set_xlabel('Tofino Surge Amplitude')

# %%
fig,ax=plt.subplots(1,1,figsize=(8,8))

for key , c in zip(lists,colors):
    time_data.plot(x='Tofino',y=key,kind='scatter',ax=ax,color=c,label=key)

ax.set_ylabel('Surge time (hours Epoch)')
ax.set_xlabel('Tofino surge teim (hours Epoch)')

# %% [markdown]
# Really not very helpful

# %%
fig,ax=plt.subplots(1,1, figsize=(8,8))

for key , c in zip(lists,colors):
    ax.plot(time_data['Tofino'] -time_data[key],'o',color=c,label=key,alpha=0.5)
ax.legend()
ax.grid()
ax.set_ylim([-10,10])
ax.set_ylabel('Offset from Tofino (hours)')

# %% [markdown]
# * Toke Point surge is often earlier than Tofino surge by a few hours
# * Neah Bay and Tofino have similar surge times usually
# * Bamfield surge super close to Tofino surge in timing
